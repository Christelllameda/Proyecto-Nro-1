# %%
# %pip install ipython
# %pip install seaborn
from dateutil.parser import parse
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

import pylab as plt  
import seaborn as sns


# %matplotlib inline

# %%
data_ori = pd.read_csv('data/attacks.csv', encoding='latin1')

data = data_ori.copy()

# %%
data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
data.shape
# Out:
# (25723, 24)

# %% [markdown]
# ## Luego de utilizar la función de 'data.info', observamos que nuestra data tiene 25.723 filas y 24 columnas, ocupando un total de 22.8 MB de memoria

# %%
data.describe().T
# Out:
#                  count         mean          std  min     25%     50%     75%  \
# Year            6300.0  1927.272381   281.116308  0.0  1942.0  1977.0  2005.0
# original order  6309.0  3155.999683  1821.396206  2.0  1579.0  3156.0  4733.0
#
#                    max
# Year            2018.0
# original order  6310.0

# %%
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# ## Buscamos si hay filas con valores nulos y procedemos a eliminarlas

# %%
filas_nulas = data[data.isnull().all(axis=1)]

# %%
filas_nulas

data = data.dropna(how='all')

# %%
data.shape

#Ahora nuestra data pasó de 25.723 filas a 8.703
# Out:
# (8703, 24)

# %%
data.tail()
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 8698            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8699            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8700            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8701            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 8698   ...      NaN                    NaN  NaN          NaN  NaN
# 8699   ...      NaN                    NaN  NaN          NaN  NaN
# 8700   ...      NaN                    NaN  NaN          NaN  NaN
# 8701   ...      NaN                    NaN  NaN          NaN  NaN
# 25722  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# ...

# %%
#Observamos que tenemos una cantidad de filas con valores nulos pero que en la columna 'Case Number'
#poseen '0' o 'xx', por lo que sustituiremos los '0' y 'xx' por nulos y eliminaremos esas filas que no son
#relevantes

data['Case Number'] = data['Case Number'].replace('0', np.nan)
data['Case Number'] = data['Case Number'].replace('xx', np.nan)
data.tail()
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 8698          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8699          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8700          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8701          NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 8698   ...      NaN                    NaN  NaN          NaN  NaN
# 8699   ...      NaN                    NaN  NaN          NaN  NaN
# 8700   ...      NaN                    NaN  NaN          NaN  NaN
# 8701   ...      NaN                    NaN  NaN          NaN  NaN
# 25722  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# ...

# %%
data = data.dropna(how='all')

# %%
data.shape
# Out:
# (6309, 24)

# %%
data.tail(15)
# Out:
#      Case Number         Date  Year        Type             Country  \
# 6294     ND.0008  Before 1906   0.0  Unprovoked           AUSTRALIA
# 6295     ND.0007  Before 1906   0.0  Unprovoked           AUSTRALIA
# 6296     ND.0006  Before 1906   0.0  Unprovoked           AUSTRALIA
# 6297     ND.0005  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903   0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905   0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889   0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)
# 6302         NaN          NaN   NaN         NaN                 NaN
# 6303         NaN          NaN   NaN         NaN                 NaN
# 6304         NaN          NaN   NaN         NaN                 NaN
# 6305         NaN          NaN   NaN         NaN                 NaN
# 6306         NaN          NaN   NaN         NaN                 NaN
# ...

# %%
filas_con_nan = np.where(data['Case Number'].isna() & data['Date'].isna())[0]
filas_con_nan
#data = data.drop(filas_con_nan)
# Out:
# array([6302, 6303, 6304, 6305, 6306, 6307, 6308])

# %%
data = data.drop(filas_con_nan)

# %%
data.shape

#Hemos eliminado filas con valores nulos, pasando a tener ahora 6.302 filas
# Out:
# (6302, 24)

# %% [markdown]
# ## Ahora observamos la cantidad de nulos que hay en nuestras columnas para luego analizar los valores que podamos sustituir

# %%
nan_cols = data.isna().sum()

nan_cols[nan_cols>0]
# Out:
# Case Number                  1
# Year                         2
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# Unnamed: 22               6301
# Unnamed: 23               6300
# dtype: int64

# %%
data['Name'].fillna('unknown', inplace=True)

#No es realmente relevante para nosotros (según nuestro objetivo) el nombre de la persona,
#por lo que sustituimos los nulos por 'unknown'

# %%
nan_cols = data.isna().sum()

nan_cols[nan_cols>0]
# Out:
# Case Number                  1
# Year                         2
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# Unnamed: 22               6301
# Unnamed: 23               6300
# dtype: int64

# %%
casenumber_null = np.where(data['Case Number'].isna())
casenumber_null

#Podemos observar que hay un Nro de caso nulo que sustituiremos por '0' ya que no afectará
#nuestra data
# Out:
# (array([5488]),)

# %%
data.loc[5488, 'Case Number'] = 0

# %%
nan_cols = data.isna().sum()

nan_cols[nan_cols>0]
# Out:
# Year                         2
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# href formula                 1
# Unnamed: 22               6301
# Unnamed: 23               6300
# dtype: int64

# %%
datos_desconocidos = ['Date', 'Year','Type','Country','Area', 'Location',
       'Activity','Sex ','Age','Injury','Fatal (Y/N)','Time','Species ','Investigator or Source','href formula','Unnamed: 22','Unnamed: 23']
data[datos_desconocidos] = data[datos_desconocidos].fillna('unknown')

# %%
nan_cols = data.isna().sum()

nan_cols[nan_cols>0]
# Out:
# Series([], dtype: int64)

# %%
data.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
filas_con_unknown = data[data['Year'] == 'unknown']

# %%
filas_con_unknown
# Out:
#        Case Number                  Date     Year        Type    Country  \
# 187   2017.01.08.R  Reported 08-Jan-2017  unknown     Invalid  AUSTRALIA
# 6079  1836.08.19.R  Reported 19-Aug-1836  unknown  Unprovoked    ENGLAND
#
#             Area    Location      Activity          Name Sex   ...  \
# 187   Queensland     unknown  Spearfishing  Kerry Daniel    M  ...
# 6079  Cumberland  Whitehaven      Swimming         a boy    M  ...
#
#         Species   Investigator or Source                           pdf  \
# 187   Bull shark  Liquid Vision 1/8/2017  2017.01.08.R-KerryDaniel.pdf
# 6079     unknown          C. Moore, GSAF   1835.08.19.R-Whitehaven.pdf
#
#                                            href formula  \
# 187   http://sharkattackfile.net/spreadsheets/pdf_di...
# 6079  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 187   http://sharkattackfile.net/spreadsheets/pdf_di...  2017.01.08.R
# ...

# %%
data.loc[187, 'Year'] = 2017
data.loc[6079, 'Year'] = 1836

# %%
data['Type'].unique()
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', 'unknown', 'Boat', 'Boatomg'], dtype=object)

# %% [markdown]
# ## Observamos que en los tipos de ataque se repite boating pero hay 2 elementos mal escritos, por lo que hacemos una función para escribirlos bien y tener las categorías bien

# %%
def limpiar_type(x):
    
    x = x.lower()
    
    if 'boat' in x:
        return 'boating'
    
    else:
        return x

# %%
data['Type'] = data['Type'].apply(limpiar_type)
data['Type'].unique()
# Out:
# array(['boating', 'unprovoked', 'invalid', 'provoked', 'questionable',
#        'sea disaster', 'unknown'], dtype=object)

# %%
type_unknown = data[data['Type'] == 'unknown']
type_unknown
# Out:
#        Case Number                  Date    Year     Type    Country  \
# 85    2017.09.15.a           15-Sep-2017  2017.0  unknown      SAMOA
# 382     2015.07.27           27-Jul-2015  2015.0  unknown  AUSTRALIA
# 4867  1936.09.11.R  Reported 11-Sep-1936  1936.0  unknown    VIETNAM
# 5705  1890.03.03.R  Reported 03-Mar-1890  1890.0  unknown     CEYLON
#
#                Area          Location           Activity           Name Sex   \
# 85     Upolu Island         Nofoalii            Fishing           male    M
# 382        Victoria  Tyrendarra Beach            Surfing           male    M
# 4867        unknown            Saigon  Wreck of a sampam         8 crew    M
# 5705        unknown           unknown             Diving  a pearl diver    M
#
#       ... Species             Investigator or Source                      pdf  \
# 85    ...  unknown         Samoa Observer, 9/16/2017   2017.09.15.a-Samoa.pdf
# ...

# %% [markdown]
# ## Teniendo la fila donde el valor del tipo de ataque es desconocido, al ser pocas filas revisamos los links donde describen el ataque y colocamos el tipo correspondiente

# %%
data.loc[85, 'Type'] = 'unprovoked'

# %%
data.loc[5705, 'Type'] = 'boating'

# %% [markdown]
# ## Observando la columna Type, no me interesan los ataques 'invalid' ya que no fueron por tiburones

# %%
data = data[data['Type'] != 'invalid']
data.shape
# Out:
# (5755, 24)

# %% [markdown]
# ## Especies

# %%
def limpiar_species(x):
    
    x = x.lower()
    
    if 'white shark' in x:
        return 'white shark'
    
    elif 'tiger shark' in x:
        return 'tiger shark'
    
    elif 'bull shark' in x:
        return 'bull shark'
    
    elif 'lemon shark' in x:
        return 'lemon shark'
    
    elif 'nurse shark' in x:
        return 'nurse shark'
    
    elif 'mako shark' in x:
        return 'mako shark'

    elif 'reef shark' in x:
        return 'reef shark'
    else:
        return x

# %%
data['Species '] = data['Species '].apply(limpiar_species)
data['Species '].unique()
# Out:
# array(['white shark', 'unknown', '2 m shark', 'tiger shark',
#        'lemon shark', 'bull shark', 'reef shark', 'nurse shark',
#        'shark involvement not confirmed', 'questionable', '3 m shark',
#        "6' shark", 'wobbegong shark', '3.5 m shark', '1.8 m shark',
#        'blacktip shark', 'galapagos shark?', 'small shark',
#        'wobbegong shark?',
#        'some drowned but other may have been killed by blue sharks',
#        'cookiecutter shark', 'wobbegong shark, 1 m',
#        'spinner shark, 4 to 5 feet', "8' shark", "5' shark",
#        "4' to 5' shark", 'porbeagle, 1.5 m', "5' to 6' shark",
#        'possibly a juvenile blacktip shark',
#        'oceanic whitetip shark, 1.8 to 2 m', "4' shark", "blue shark 6'",
#        '"a small shark"', 'seven-gill shark',
#        '3m shark, probably a smooth hound', "3' shark", "9' shark",
#        "10' shark", 'a small shark', 'wobbegong shark, 2m',
#        'broadnose sevengill shark, 1.5 m', " 6' to 8' shark",
# ...

# %% [markdown]
# ## Revisamos la columna de 'Fatal (Y/N)'

# %%
unknown = data[data['Fatal (Y/N)'] == 'unknown']
unknown
# Out:
#        Case Number                  Date    Year          Type  \
# 27    2018.04.15.c           15-Apr-2018  2018.0    unprovoked
# 269   2016.06.02.b           02-Jun-2016  2016.0    unprovoked
# 294   2016.03.28.b           28-Mar-2016  2016.0    unprovoked
# 382     2015.07.27           27-Jul-2015  2015.0       unknown
# 1292    2008.01.30            2008.01.30  2008.0      provoked
# 3452    1968.11.04           04-Nov-1968  1968.0  sea disaster
# 3506    1967.09.13           13-Sep-1967  1967.0      provoked
# 4127    1958.12.28           28-Dec-1958  1958.0       boating
# 4333    1954.07.27           27-Jul-1954  1954.0       boating
# 5630    1895.09.18           18-Sep-1895  1895.0  sea disaster
# 5945    1864.04.09           09-Apr-1864  1864.0    unprovoked
# 6104  1826.08.15.R  Reported 15-Aug-1826  1826.0    unprovoked
# 6122  1808.06.01.R  Reported 01-May-1808  1808.0  sea disaster
# 6125    1806.04.24           Aug-24-1806  1896.0  sea disaster
# ...

# %% [markdown]
# ## Viendo los valores desconocidos en la columna Fatal (Y/N), podemos encontrar que según la descripción de la columna Injury, tenemos datos para saber si la persona murió o no

# %%
data.loc[27, 'Fatal (Y/N)'] = 'N'
data.loc[269, 'Fatal (Y/N)'] = 'N'
data.loc[294, 'Fatal (Y/N)'] = 'N'
data.loc[382, 'Fatal (Y/N)'] = 'N'
data.loc[1292, 'Fatal (Y/N)'] = 'N'
data.loc[3452, 'Fatal (Y/N)'] = 'Y'
data.loc[3506, 'Fatal (Y/N)'] = 'N'
data.loc[4127, 'Fatal (Y/N)'] = 'N'
data.loc[4333, 'Fatal (Y/N)'] = 'N'
data.loc[5630, 'Fatal (Y/N)'] = 'Y'
data.loc[5945, 'Fatal (Y/N)'] = 'N'
data.loc[6104, 'Fatal (Y/N)'] = 'Y'
data.loc[6122, 'Fatal (Y/N)'] = 'Y'
data.loc[6125, 'Fatal (Y/N)'] = 'Y'
data.loc[6158, 'Fatal (Y/N)'] = 'N'

# %%
data['Fatal (Y/N)'].unique()
# Out:
# array(['N', 'Y', 'M', 'UNKNOWN', '2017', ' N', 'N ', 'y'], dtype=object)

# %%
def limpiar_fatal(x):
    
    x = x.lower()
    
    if 'n' in x:
        return 'N'
    elif 'y' in x:
        return 'Y'
    else:
        return x

# %%
data['Fatal (Y/N)'] = data['Fatal (Y/N)'].apply(limpiar_fatal)
data['Fatal (Y/N)'].unique()
# Out:
# array(['N', 'Y', 'm', '2017'], dtype=object)

# %%
filas_con_unknown = data[data['Fatal (Y/N)'] == 'm']
filas_con_unknown
# Out:
#       Case Number         Date    Year      Type           Country      Area  \
# 285  2016.04.18.b  18-Apr-2016  2016.0  provoked  FRENCH POLYNESIA  Tuamotos
#
#          Location      Activity         Name Sex   ...    Species   \
# 285  Makemo Atoll  Spearfishing  Hoata Iotua    M  ...  reef shark
#
#     Investigator or Source                     pdf  \
# 285   TNTV News, 4/19/2016  2016.04.18.b-Iotua.pdf
#
#                                           href formula  \
# 285  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 285  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.04.18.b
#
#     Case Number.2 original order Unnamed: 22 Unnamed: 23
# 285  2016.04.18.b         6018.0     unknown     unknown
#
# [1 rows x 24 columns]

# %% [markdown]
# ## Tenemos un valor 'm' en la columna Fatal (Y/N) y revisando la columna de injury, podemos ver que no murió por lo que asignamos una 'N'

# %%
data.loc[285, 'Fatal (Y/N)'] = 'N'

# %%
#data['Year'] = pd.to_datetime(data['Year'], format='%Y')

# %%
filas_con_unknown = data[data['Fatal (Y/N)'] == '2017']
filas_con_unknown
# Out:
#     Case Number         Date    Year      Type Country      Area  Location  \
# 786  2012.06.10  10-Jun-2012  2012.0  provoked   ITALY  Sardinia  Muravera
#
#                                             Activity          Name Sex   ...  \
# 786  Attempting to rescue an injured & beached shark  Giorgio Zara    M  ...
#
#              Species  Investigator or Source                  pdf  \
# 786  blue shark, 2.5m    D. Puddo, 6/11/2012  2012.06.10-Zara.pdf
#
#                                           href formula  \
# 786  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 786  http://sharkattackfile.net/spreadsheets/pdf_di...    2012.06.10
#
#     Case Number.2 original order Unnamed: 22 Unnamed: 23
# 786    2012.06.10         5517.0     unknown     unknown
#
# [1 rows x 24 columns]

# %%
data.loc[786, 'Fatal (Y/N)'] = 'N'

# %% [markdown]
# ## Chequeamos de nuevo los valores únicos de la columna Fatal (Y/N)

# %%
data['Fatal (Y/N)'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %% [markdown]
# ## Cambiamos el tipo de dato de la columna Year (que era float) a entero

# %%
data['Year'] = data['Year'].astype(int)

# %% [markdown]
# ## Revisamos la columna de género para ordenar los valores y filtrar

# %%
data['Sex '].unique()
# Out:
# array(['F', 'M', 'unknown', 'M ', 'lli', 'N', '.'], dtype=object)

# %%
data = data[data['Sex '] != '.']

# %%
data = data[data['Sex '] != 'lli']

# %%
def limpiar_fecha(x):
    
    x = x.lower()
    
    if 'm' in x:
        return 'M'
    elif 'f' in x:
        return 'F'
    if 'n' in x:
        return 'N'
    elif 'f' in x:
        return 'F'
    else:
        return x

# %%
data['Sex '] = data['Sex '].apply(limpiar_fecha)
data['Sex '].unique()
# Out:
# array(['F', 'M', 'N'], dtype=object)

# %% [markdown]
# ## ## Revisamos la columna de Fecha para ordenar los valores y filtrar

# %%
data['Date'].unique()
# Out:
# array(['25-Jun-2018', '18-Jun-2018', '08-Jun-2018', ..., '1900-1905',
#        '1883-1889', '1845-1853'], dtype=object)

# %%
data['Date'] = data['Date'].str.replace('Reported', '').str.strip()

# %%
data = data[data['Date'] != 'may 2018']

# %%
def try_parsing_date(text):
    for fmt in ('%d-%b-%Y', '%b %Y'):
        try:
            return pd.to_datetime(parse(text).strftime('%d-%b-%Y'), format='%d-%b-%Y')
        except ValueError:
            pass
    return pd.NaT  # Valor nulo si no se puede parsear

data['Date'] = data['Date'].apply(try_parsing_date)

# %%
data.rename(columns={'Unnamed: 22': 'Day'}, inplace=True)
data.rename(columns={'Unnamed: 23': 'Month'}, inplace=True)

# %%
data['Day'] = data['Date'].dt.day

# %%
count_null_values = data['Day'].isnull().sum()
count_null_values
# Out:
# 753

# %%
count_null_values = data['Date'].isnull().sum()
count_null_values
# Out:
# 753

# %%
count_null_values_mes = data['Month'].isnull().sum()
count_null_values_mes
# Out:
# 753
